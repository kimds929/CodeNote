# %%
import numpy as np
import pandas as pd

import missingno as msno
import httpimport
import importlib
import requests

# %%
# !pip install missingno

# %%
# response_DS_DataFrame = requests.get("https://raw.githubusercontent.com/kimds929/DS_Library/main/DS_DataFrame.py")
# response_DS_Plot = requests.get("https://raw.githubusercontent.com/kimds929/DS_Library/main/DS_Plot.py")
# response_DS_MachineLearning = requests.get("https://raw.githubusercontent.com/kimds929/DS_Library/main/DS_MachineLearning.py")
# response_DS_DeepLearning = requests.get("https://raw.githubusercontent.com/kimds929/DS_Library/main/DS_DeepLearning.py")
# response_DS_Torch = requests.get("https://raw.githubusercontent.com/kimds929/DS_Library/main/DS_Torch.py")

# exec(response_DS_DataFrame.text)
# exec(response_DS_Plot.text)
# exec(response_DS_MachineLearning.text)
# exec(response_DS_DeepLearning.text)
# exec(response_DS_Torch.text)

# %%
remote_library_url = 'https://raw.githubusercontent.com/kimds929/'
remote_data_url = 'https://raw.githubusercontent.com/kimds929/CodeNote/main/99_DataSet/'

# %%
importlib.reload(httpimport)
# Out:
# <module 'httpimport' from '/usr/local/lib/python3.10/dist-packages/httpimport.py'>

# %%
with httpimport.remote_repo(f"{remote_library_url}/DS_Library/main/"):
    from DS_DeepLearning import EarlyStopping

# %%
with httpimport.remote_repo(f"{remote_library_url}/DS_Library/main/"):
    # import DF_DataFrame
    from DS_DataFrame import DF_Summary
# Out:
# <string>:311: SyntaxWarning: "is" with a literal. Did you mean "=="?

# %%
with httpimport.remote_repo(f"{remote_library_url}/DS_Library/main/"):
    from DS_Plot import ttest_each, violin_box_plot, distbox

# %%
with httpimport.remote_repo(f"{remote_library_url}/DS_Library/main/"):
    from DS_MachineLearning import ScalerEncoder, DataSet

# %%
df_titanic = pd.read_csv(f"{remote_data_url}/Data_Tabular/titanic.csv", encoding="utf-8-sig")
df_titanic
# Out:
#       pclass  survived     sex      age  sibsp  parch      fare embarked
# 0        1.0       1.0  female  29.0000    0.0    0.0  211.3375        S
# 1        1.0       1.0    male   0.9167    1.0    2.0  151.5500        S
# 2        1.0       0.0  female   2.0000    1.0    2.0  151.5500        S
# 3        1.0       0.0    male  30.0000    1.0    2.0  151.5500        S
# 4        1.0       0.0  female  25.0000    1.0    2.0  151.5500        S
# ...      ...       ...     ...      ...    ...    ...       ...      ...
# 1305     3.0       0.0  female      NaN    1.0    0.0   14.4542        C
# 1306     3.0       0.0    male  26.5000    0.0    0.0    7.2250        C
# 1307     3.0       0.0    male  27.0000    0.0    0.0    7.2250        C
# 1308     3.0       0.0    male  29.0000    0.0    0.0    7.8750        S
# 1309     NaN       NaN     NaN      NaN    NaN    NaN       NaN      NaN
#
# [1310 rows x 8 columns]

# %%
df_summary = DF_Summary(df_titanic)
# Out:
# (2,) (6,) (0,)
# 82.0+ KB  |  8 columns  1,310 obs
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>dtype</th>
#       <th>missing</th>
#       <th>info</th>
#       <th>sample</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>pclass</th>
#       <td>float64</td>
#       <td>1 (0.1 %)</td>
#       <td>3 counts</td>
#       <td>[3.0, 1.0, 2.0]</td>
#     </tr>
#     <tr>
#       <th>survived</th>
#       <td>float64</td>
#       <td>1 (0.1 %)</td>
#       <td>2 counts</td>
#       <td>[0.0, 1.0]</td>
#     </tr>
#     <tr>
#       <th>sex</th>
#       <td>object</td>
#       <td>1 (0.1 %)</td>
#       <td>2 levels</td>
#       <td>['male', 'female']</td>
#     </tr>
#     <tr>
#       <th>age</th>
#       <td>float64</td>
#       <td>264 (20.2%)</td>
#       <td>29.9   (14.41 ) 0.2    ~ 80.0</td>
#       <td>[24.0, 22.0, 21.0, 3</td>
#     </tr>
#     <tr>
#       <th>sibsp</th>
#       <td>float64</td>
#       <td>1 (0.1 %)</td>
#       <td>7 counts</td>
#       <td>[0.0, 1.0, 2.0, 4.0,</td>
#     </tr>
#     <tr>
#       <th>parch</th>
#       <td>float64</td>
#       <td>1 (0.1 %)</td>
#       <td>8 counts</td>
#       <td>[0.0, 1.0, 2.0, 3.0,</td>
#     </tr>
#     <tr>
#       <th>fare</th>
#       <td>float64</td>
#       <td>2 (0.2 %)</td>
#       <td>33.3   (51.76 ) 0.0    ~ 512.3</td>
#       <td>[8.05, 13.0, 7.75, 2</td>
#     </tr>
#     <tr>
#       <th>embarked</th>
#       <td>object</td>
#       <td>3 (0.2 %)</td>
#       <td>3 levels</td>
#       <td>['S', 'C', 'Q']</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df_summary.summary
# Out:
#             dtype      missing                             info  \
# pclass    float64    1 (0.1 %)                         3 counts
# survived  float64    1 (0.1 %)                         2 counts
# sex        object    1 (0.1 %)                         2 levels
# age       float64  264 (20.2%)  29.9   (14.41 ) 0.2    ~ 80.0
# sibsp     float64    1 (0.1 %)                         7 counts
# parch     float64    1 (0.1 %)                         8 counts
# fare      float64    2 (0.2 %)  33.3   (51.76 ) 0.0    ~ 512.3
# embarked   object    3 (0.2 %)                         3 levels
#
#                         sample
# pclass         [3.0, 1.0, 2.0]
# survived            [0.0, 1.0]
# sex         ['male', 'female']
# age       [24.0, 22.0, 21.0, 3
# sibsp     [0.0, 1.0, 2.0, 4.0,
# parch     [0.0, 1.0, 2.0, 3.0,
# fare      [8.05, 13.0, 7.75, 2
# embarked       ['S', 'C', 'Q']

# %%
df_summary.summary_plot()
# Out:
# 0it [00:00, ?it/s]
# <string>:1862: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# <string>:1862: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
msno.matrix(df_titanic)
# Out:
# <Axes: >

# %%
df_titanic2 = df_titanic[~df_titanic.isna().any(axis=1)]

# %%
msno.matrix(df_titanic2)
# Out:
# <Axes: >

# %%
df_titanic2['pclass'] = df_titanic2['pclass'].astype(object)
df_titanic2['survived'] = df_titanic2['survived'].astype(object)
# Out:
# <ipython-input-27-c3e967c9b811>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_titanic2['pclass'] = df_titanic2['pclass'].astype(object)
# <ipython-input-27-c3e967c9b811>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_titanic2['survived'] = df_titanic2['survived'].astype(object)

# %%
DF_Summary(df_titanic2)
# Out:
# (4,) (4,) (0,)
# 73.3+ KB  |  8 columns  1,043 obs
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>dtype</th>
#       <th>missing</th>
#       <th>info</th>
#       <th>sample</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>pclass</th>
#       <td>object</td>
#       <td>-</td>
#       <td>3 levels</td>
#       <td>[3.0, 1.0, 2.0]</td>
#     </tr>
#     <tr>
#       <th>survived</th>
#       <td>object</td>
#       <td>-</td>
#       <td>2 levels</td>
#       <td>[0.0, 1.0]</td>
#     </tr>
#     <tr>
#       <th>sex</th>
#       <td>object</td>
#       <td>-</td>
#       <td>2 levels</td>
#       <td>['male', 'female']</td>
#     </tr>
#     <tr>
#       <th>age</th>
#       <td>float64</td>
#       <td>-</td>
#       <td>29.8   (14.37 ) 0.2    ~ 80.0</td>
#       <td>[24.0, 22.0, 21.0, 3</td>
#     </tr>
#     <tr>
#       <th>sibsp</th>
#       <td>float64</td>
#       <td>-</td>
#       <td>7 counts</td>
#       <td>[0.0, 1.0, 2.0, 4.0,</td>
#     </tr>
#     <tr>
#       <th>parch</th>
#       <td>float64</td>
#       <td>-</td>
#       <td>7 counts</td>
#       <td>[0.0, 1.0, 2.0, 3.0,</td>
#     </tr>
#     <tr>
#       <th>fare</th>
#       <td>float64</td>
#       <td>-</td>
#       <td>36.6   (55.75 ) 0.0    ~ 512.3</td>
#       <td>[13.0, 26.0, 8.05, 1</td>
#     </tr>
#     <tr>
#       <th>embarked</th>
#       <td>object</td>
#       <td>-</td>
#       <td>3 levels</td>
#       <td>['S', 'C', 'Q']</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
ttest_each(data=df_titanic2, x='age', group='pclass')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-befbfb3fa873> in <cell line: 1>()
# ----> 1 ttest_each(data=df_titanic2, x='age', group='pclass')
#
# https://raw.githubusercontent.com/kimds929//DS_Library/main/DS_Plot.py in ttest_each(data, x, group, equal_var, decimal_point, return_result, return_type)
#
# KeyError: 2.0

# %%
violin_box_plot(data=df_titanic2, x='pclass', y='age')

# %%
distbox(data=df_titanic2, on='age', group='pclass')
# Out:
# <string>:392: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# <string>:392: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# <string>:392: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# pclass
# <string>:417: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.

# %%
df_titanic2
# Out:
#      pclass survived     sex      age  sibsp  parch      fare embarked
# 0       1.0      1.0  female  29.0000    0.0    0.0  211.3375        S
# 1       1.0      1.0    male   0.9167    1.0    2.0  151.5500        S
# 2       1.0      0.0  female   2.0000    1.0    2.0  151.5500        S
# 3       1.0      0.0    male  30.0000    1.0    2.0  151.5500        S
# 4       1.0      0.0  female  25.0000    1.0    2.0  151.5500        S
# ...     ...      ...     ...      ...    ...    ...       ...      ...
# 1301    3.0      0.0    male  45.5000    0.0    0.0    7.2250        C
# 1304    3.0      0.0  female  14.5000    1.0    0.0   14.4542        C
# 1306    3.0      0.0    male  26.5000    0.0    0.0    7.2250        C
# 1307    3.0      0.0    male  27.0000    0.0    0.0    7.2250        C
# 1308    3.0      0.0    male  29.0000    0.0    0.0    7.8750        S
#
# [1043 rows x 8 columns]

# %%
se = ScalerEncoder()

# %%
df_titanic_transformed = se.fit_transform(df_titanic2)
df_titanic_transformed
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
#       pclasslass_2.0  pclasslass_3.0  survivedrvived_1.0  sexx_male       age  \
# 0                  0               0                   1          0 -0.056632
# 1                  0               0                   1          1 -2.012379
# 2                  0               0                   0          0 -1.936937
# 3                  0               0                   0          1  0.013009
# 4                  0               0                   0          0 -0.335196
# ...              ...             ...                 ...        ...       ...
# 1301               0               1                   0          1  1.092443
# 1304               0               1                   0          0 -1.066425
# 1306               0               1                   0          1 -0.230734
# 1307               0               1                   0          1 -0.195914
# 1308               0               1                   0          1 -0.056632
#
#          sibsp     parch      fare  embarkedbarked_Q  embarkedbarked_S
# 0    -0.552587 -0.502064  3.135549                 0                 1
# 1     0.543133  1.878176  2.062683                 0                 1
# 2     0.543133  1.878176  2.062683                 0                 1
# 3     0.543133  1.878176  2.062683                 0                 1
# 4     0.543133  1.878176  2.062683                 0                 1
# ...        ...       ...       ...               ...               ...
# 1301 -0.552587 -0.502064 -0.527178                 0                 0
# 1304  0.543133 -0.502064 -0.397453                 0                 0
# 1306 -0.552587 -0.502064 -0.527178                 0                 0
# 1307 -0.552587 -0.502064 -0.527178                 0                 0
# 1308 -0.552587 -0.502064 -0.515514                 0                 1
#
# [1043 rows x 10 columns]

# %%
se.inverse_transform(df_titanic_transformed)
# Out:
#      pclass survived     sex      age  sibsp         parch      fare embarked
# 0       1.0      1.0  female  29.0000    0.0  5.551115e-17  211.3375        S
# 1       1.0      1.0    male   0.9167    1.0  2.000000e+00  151.5500        S
# 2       1.0      0.0  female   2.0000    1.0  2.000000e+00  151.5500        S
# 3       1.0      0.0    male  30.0000    1.0  2.000000e+00  151.5500        S
# 4       1.0      0.0  female  25.0000    1.0  2.000000e+00  151.5500        S
# ...     ...      ...     ...      ...    ...           ...       ...      ...
# 1301    3.0      0.0    male  45.5000    0.0  5.551115e-17    7.2250        C
# 1304    3.0      0.0  female  14.5000    1.0  5.551115e-17   14.4542        C
# 1306    3.0      0.0    male  26.5000    0.0  5.551115e-17    7.2250        C
# 1307    3.0      0.0    male  27.0000    0.0  5.551115e-17    7.2250        C
# 1308    3.0      0.0    male  29.0000    0.0  5.551115e-17    7.8750        S
#
# [1043 rows x 8 columns]
